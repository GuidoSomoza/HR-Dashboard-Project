# %% [markdown]
# <a href="https://colab.research.google.com/github/GuidoSomoza/GuidoSomoza/blob/main/Project_Human_Resources_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRO
# Este projecto tiene como finalidad poder entender el gasto del area de Recursos humanos y con ello detectar highs and lows. Para realizar este projecto se conecto la base de datos que agrupaba los gastos a Power bi y se realizó un dashboard con los KPIS a analizar utilzando DAX y Conexiones entre bases.
#
# This project try to understand the spent budget of Human Resources seeking for highs and lows in this task. To realize this project i use a dataset of RRHH which had the necesitary records to build a dashboard showing KPIS using DAX & conextions skils.
#
# DATASET and BACKGROUND FROM: https://www.youtube.com/@visualsdata
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PASO 1 CONEXIÓN CON POWER BI  /  STEP 1 CONECT TO POWER BI
#
# En este caso la base de datos ya estaba organizada de manera que no necesitamos utilizar Data wrangling, por ende directamente conectamos la base a Power BI.
#
# Luego de eso debemos seleccionar las tablas con las que queremos trabajar y seleccionar "cargar".
#
# DATASET( descargar toda la carpeta) :  https://drive.google.com/drive/folders/1xz_ZAFi-Itk3XYESzDvKTqES8-2TFA0h?usp=share_link
#
# In this first Step the data set is clean to use so we dont't need to do Data wrangling so we can conect the data with power bi.
#
#
# DATASET ( Download entire folder) :  https://drive.google.com/drive/folders/1xz_ZAFi-Itk3XYESzDvKTqES8-2TFA0h?usp=share_link
#
# ![get data.PNG](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PASO 2 CONFIGURAR FONDO / STEP 2 SET BACKGROUND
#
# En este paso deberemos ir a la configuración de nuestra página e importar nuestro lienzo previamente descargado con nuestra base de datos. importante dejar la transperencia en 0.
#
# In this step we have to go to settings of the page and import our background that previously we download. Important set the transparency at 0.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #PASO 3 RELACIONES DE DATOS / STEP 3 DATA RELATIONS
#
# En este punto relacionaremos las diferentas tablas para que a la hora de trabajar con visualizaciones podramos vincular datos independientemente a que tabla pertenezca. En este caso relacionaremos las tablas donde el valor se repita en las tablas que estamos relacionando, vincularemos "cuenta" entre gastos1 y presupuesto2. Luego vincularemos Fecha entre gastos1 y calendario.
#
#
# In this step we gona match the tables so we can use the data of any table in the next steps. We gonna relate the tables with the key that repits in both tables. We have to relate the key "cuenta" between gastos1 & presupuesto2 and gastos1 and calendario with the key "fecha".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #PASO 4 MEDIDAS RAPIDAS DAX / STEP 4 DAX MEDIA
# En este paso tendremos que realizar 4 medidas que vamos a necesitar para realizar las visualizaciones:
# *   Tabla **gastos 01** - % de Gasto = divide([Total Gastado],[Total Presupuesto],0)
# *   Tabla **gastos 01** - Saldo = [Total Presupuesto] - [Total Gastado]
# *   Tabla **gastos 01** - Total Gastado = sum(Gastos1[Gastos])
# *   Tabla **presupuesto2** - Total Presupuesto = sum(Presupuesto2[Presupuesto Anual])
#
#
# In this step we have to realize 4 DAX medias that we gonna use in the visualizations:
# *   Table **gastos 01** - % de Gasto = divide([Total Gastado],[Total Presupuesto],0)
# *   Table **gastos 01** - Saldo = [Total Presupuesto] - [Total Gastado]
# *   Table **gastos 01** - Total Gastado = sum(Gastos1[Gastos])
# *   Table **presupuesto2** - Total Presupuesto = sum(Presupuesto2[Presupuesto Anual])
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PASO 5 CREANDO VISUALIZACIONES / STEP 5 CREATING VISUALIZATIONS
#
# En este paso ya comenzamos a modelar datos y de esta manera entender mejor los datos que calculamos. Crearemos las siguiente visualizaciones:
# * Medidor : Con esta visualización buscaremos explicar en que estado esta el gasto vs el presupuesto destinado a gastar
# * Tarjetas : Crearemos 3 tarjetas con KPIS que nos permitan entender en mayor profundidad cuanto se gasto, cuanto nos queda disponible y cual era el total del presupuesto
# * Graficos de barras agrupadas: En esta visualización buscaremos entender como fue distribuido el presupuesto
# * Graficos de barras apiladas: Mostraremos la distribución del presupuesto en cada Trimestre
# * Graficos de lineas: En esta visualización veremos la distribución del gasto durante los meses
# * Grafico de anillo: En este grafico veremos la comparación del gasto entre los semestres
# * Matriz: En este grafico buscaremos entender en que categorías hubo mayor gasto y cuanta representatividad del gasto tiene cada una
#
# In this step we start to create visualizations and understand better the Dax medias we calculate before. We gonna build this visualitations:
# * Meditor: In this visualitation we seek to understand the budget vs the budget spend
# * Targets: In this visualitation we gonna show some kpis ( Budget spent, Budget available to spent and Total Budget)
# * Clustered bars: In this graphic we gonna see the distribution of the budget spent by category
# * Stacked bars: In this graphic we gonna see the spent of budget by quarter
# * Line Graph: Here we gonna see the budget spent by month to sear variations on the spent budget and understand why
# * Ring Chart: In this visualitation we want to show the spent budget by semester and compare one to each other
# * Matrix Chart: Here we seek to understand the representativeness of budget spent by category

# %% [markdown]
# # CONFIGURACIONES GRAFICAS / GRAPHICS SETTINGS
#
# Paleta de colores:
# Hex: #94F8FD
#
# RGB: 148,248,253
#
# Hex: #1B1B2D
#
# RGB: 27,27,45
#
# Hex: #13121D
#
# RGB: 19,18,29
#
# Fuente:
#
# Segoe UI
#
# Iconos:
# flaticon.es
#
#
# Color palette:Hex: #94F8FD
#
# RGB: 148,248,253
#
# Hex: #1B1B2D
#
# RGB: 27,27,45
#
# Hex: #13121D
#
# RGB: 19,18,29
#
# Font:
#
# Segoe UI
#
# Icons:
#
# flaticon.es

# %% [markdown]
# # INSIGHTS Y CONCLUSIONES
#
# En base a lo analizado podemos ver:
# * Se debe analizar ser mas cauteloso con el gasto ya que faltando 4 meses para terminar el año el area ya ha gastado un 75% por lo cual podemos entender que se gasto un 10% más de lo previsto por mes
# * El area esta haciendo mucho foco en incentivos para retener a los empleados mientras, el area podría trabajar sobre el motivo de retener empleados y tratar de buscar desafíos que generen una necesidad de capacitaión ( donde el margen es mayor para gastar)
# * El area deberá tratar de buscar que los gastos de horas extras puedan transferirse a gastos de selección con el fin de buscar nuevos empleados y asi evitar que los trabajadores tengan que realizar horas extras
#
# In base of what we see in the dashboard:
# * The area have analyze the spent of the budget because with 4 months left the budget spent rate is in 75%, that means that HR have spent a 10% more than expected
# * The team is spending so much budget incentives to retain the workers, the area can work in motivation of the workers looking to teach new skills and spent budget in training new skills
#
# * The team can work to move the spent budget on extras hours to recruiting and incorporate new people and decrease the need of extra hours
#
#
#
# ![image.png](data:image/png;base64,...)
